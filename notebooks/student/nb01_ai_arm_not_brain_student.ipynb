# %% [markdown]
# # Studio 1: Frame the Inquiry (from curiosity to a research problem)
#
# **Topic 01 · 2 lectures**
#
# <hr>
#
# <center>
# <div>
# <img src="https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/images/edrai_logo.png" width="300"/>
# </div>
# </center>
#
#
# # <center><a class="tocSkip"></center>
# # <center>HONR 46400 — Evidence-Driven Research</center>
# # <center>Professor: Davi Moreira</center>
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/blob/main/notebooks/student/nb01_ai_arm_not_brain_student.ipynb)
#
# ---

# %% [markdown]
# ## 🧭 Inquiry & Claim Boundary
#
# *Every notebook in this course opens with this panel, so here is how to read it.
# **Inquiry emphasis** names the kind of question the week trains you to ask.
# **Design pathway** places the week on the course's map of research designs. The
# claim table then draws the week's line: what your work permits you to claim, and
# what it does not.*
#
# **Inquiry emphasis:** all positions (framing). This week does not classify
# questions. It does the thing that has to happen first: you commit to a curiosity
# you own and choose the research problem you are willing to chase. The map that
# sorts questions by kind and reach, the **inquiry compass**, opens next week.
#
# **Design pathway:** cross-cutting. Framing comes before any design. The working
# rule you set here travels into all five design pathways later in the course:
# observational descriptive, observational causal, experimental descriptive,
# experimental causal, and prediction.
#
# | | |
# |---|---|
# | **A claim this topic PERMITS** | "This is the curiosity I own, and this is the problem I chose, with reasons I can defend and a trail of what I rejected." |
# | **A claim this topic does NOT permit** | "This problem is new." Whether anyone has already answered it is a question you cannot settle until you map the existing evidence in Studio 3, so possible contribution stays provisional. |
#
# **Where this sits in the course:** Week 1, the first studio of the book and of
# the course. Monday sets up how the course works and the one rule behind it.
# Wednesday teaches the book's opening lesson. Friday builds **Milestone 1: Your
# curiosity, committed**, which the course carries as milestone **M1**.

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# 1. Run your laboratory and confirm it works: run a cell, load a course dataset,
#    and claim this notebook with your own name.
# 2. State the course promise in one line, and name the research decisions you
#    never hand to a tool.
# 3. Check a generated result yourself, and say plainly what a clean run does and
#    does not establish.
# 4. Walk a curiosity down the funnel, from **experience** to **research problem**,
#    and say what each stop adds.
# 5. Direct your AI assistant as a divergence partner, mark everything it
#    introduces as NEW, and reject any stretch that changed who, what, or why.
# 6. Commit to one research problem for your own project, as the dated version zero
#    of Milestone 1.
#
# ---

# %% [markdown]
# ## ⚙️ Setup
#
# Before anything else, get your laboratory running. Run the cell below. Every
# notebook in this course starts the same way, so this takes about a minute from
# Week 2 on.

# %%
# Setup — run this cell first.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option("display.max_columns", None)
pd.set_option("display.precision", 3)
plt.rcParams["figure.figsize"] = (9, 5)

SEED = 464  # course number — keeps every simulation reproducible
rng = np.random.default_rng(SEED)

# Data loads: GitHub raw URL first (works in Colab), local repo path as fallback.
DATA_URL = ("https://raw.githubusercontent.com/davi-moreira/"
            "2026F_evidence_driven_research_purdue_HONR464/main/notebooks/data/")

def load_course_data(filename):
    """Load a course dataset from GitHub, falling back to the local repo copy."""
    try:
        return pd.read_csv(DATA_URL + filename)
    except Exception:
        from pathlib import Path
        local = Path("notebooks/data") / filename
        if not local.exists():
            local = Path("../data") / filename
        return pd.read_csv(local)

print("✓ Setup complete — seed", SEED)
# Out:
# ✓ Setup complete — seed 464

# %% [markdown]
# **Reading the output.** The setup cell prints one line: `✓ Setup complete
# — seed 464`. That seed pins every simulation in the course, so your numbers and
# your neighbor's numbers always match. If the line did not print, flag it now
# rather than in Week 5.

# %% [markdown]
# # Lecture 1

# %% [markdown]
# ### 🎤 SRL Lead Brief
#
# *Every Monday and Wednesday lecture in this course opens with this section. It
# belongs to the day's **Student Research Lead**: the classmate who runs the room.*
#
# This week is the exception. Both Week 1 lectures are led from the front, so you
# see the format modeled before you inherit it. Watch three things closely:
#
# 1. How the opening puzzle gets posed, and how little exposition comes before it.
# 2. How everyone commits an answer in writing before any tool is opened.
# 3. How the investigation is steered with questions rather than answered from the
#    front.
#
# That is the job. From next week on, one of you runs each Monday and Wednesday
# lecture. The slots are **drawn at random today**, and they are yours for the
# term: five lectures each, nothing rotating and nothing shifting. Your lead's
# brief sits exactly here inside that lecture's notebook, visible to everyone
# rather than to the lead alone, and it is a floor rather than a ceiling. The frame
# is fixed; the staging is yours.
#
# When your turn comes, read your brief about a week ahead. Then work the rest of
# that notebook and its required chapters as a learner, so you have sat with every
# answer before you ask anyone else to reach it, and decide the one thing *you* are
# adding that the brief does not have: your own example, your own opening question,
# one move it never thought of. On the day, arrive a few minutes early, open Colab,
# confirm your AI tool answers, and have a fallback ready in case it does not. If
# you ever have to miss a slot, tell your instructor as far ahead as you can.
# Swapping with a classmate's later slot, by agreement, is the first option, and it
# is far easier to arrange in advance than on the morning of.

# %% [markdown]
# ## 1. Who Is in the Room
#
# **Guiding question:** *who are you working with for the next sixteen weeks, and
# what is each of you curious about?*
#
# <center>
# <img src="https://raw.githubusercontent.com/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/main/images/professor/davi_moreira_photo.JPG" width="160">
# </center>
#
# <center>
#
# [dcordeir@purdue.edu](mailto:dcordeir@purdue.edu) · [davi-moreira.github.io](https://davi-moreira.github.io/)
#
# </center>
#
# I am a Clinical Assistant Professor in the Quantitative Methods Department and
# Director of the Daniels Undergraduate Business Honors Program at Purdue. My
# academic work covers Political Communication, Data Science, Text as Data,
# Artificial Intelligence, and Comparative Politics. I also work as a
# [Monitoring and Evaluation Specialist consultant for the World
# Bank](https://blogs.worldbank.org/opendata/improving-how-we-measure-progress-community-biodiversity-conservation-projects-mozambique)
# in Brazil, Mozambique, Angola, and the Democratic Republic of the Congo, which
# is where I learned how expensive a confident wrong number can be.
#
# Two curiosities keep me honest about uncertainty. **Palmeiras**, the greatest
# Brazilian football club and the source of my most rigorous training in
# probability. And **Carnaval de Olinda**, my hometown street carnival in
# Pernambuco, famous for its giant puppets.
#
# <center>
# <img src="https://raw.githubusercontent.com/davi-moreira/2026F_evidence_driven_research_purdue_HONR464/main/images/professor/carnaval_olinda.jpg" width="300">
# </center>
#
# <center>
#
# [The most exciting game in history (video)](https://www.youtube.com/watch?v=FCebgeX_3hI&t=89s) · [NYT: how John Travolta became the star of Carnival](https://www.nytimes.com/2024/02/13/world/americas/brazil-carnival-john-travolta.html)
#
# </center>

# %% [markdown]
# ### Now It Is Your Turn
#
# Thirty seconds each, around the room: your name, your field, and one thing you
# are genuinely curious about. Say the curiosity in one sentence, even a rough one.
# Those sentences go on the board and stay there, because by the end of this week
# one of them becomes the problem you chase all semester.

# %% [markdown]
# ### 🤝 AI Research Partner
#
# All semester you work with **AI as a research partner**, not an answer machine. A
# **research partner** is a tool you task with real work and then check, the way you
# would check a fast but unproven research assistant. And AI today is more than a
# chatbot: **agentic tools** can carry out multi-step work for you, running an
# analysis plan, trying variations, assembling a draft. It is fine to ask your AI to
# *do* things, not only to answer things. The deal never changes: you review, you
# curate, and you make the final decision.
#
# AI is also a good partner for **brainstorming**: candidate questions, rival
# explanations, directions you had not considered. Generate widely with it; commit
# narrowly yourself. A good use looks like this: you commit your own answer first,
# then ask your AI to stretch it, list items you will check, or explain a cell so
# you can confirm it against the printed output. A bad use is letting it decide your
# question, wave a claim past your evidence, or hand you a source you never opened.
#
# **Never delegate these:** which problem and question you pursue, which claims your
# evidence justifies, the ethics of your study, and how you state your uncertainty.
# The full account is next week's reading,
# [Research Responsibility and Intellectual Ownership](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/part1-research-with-ai/04-research-responsibility-and-intellectual-ownership.html).
#
# **Commit first, then ask.** Every AI block in this course asks you to write your
# own answer before you open your tool, so the reply has something of yours to
# disagree with.
#
# > **A question that often comes up here:** *"If AI is faster and often right, why
# > write my answer first?"* Because the habit protects your judgment. If you read
# > the tool's answer first, it anchors you, and you lose the one thing you bring
# > that it cannot: knowing what your project is really about. Writing first keeps
# > you the researcher and keeps AI the assistant.
#
# ---

# %% [markdown]
# ### 🧩 Research Puzzle
#
# *(This one runs with no laptops and no tool. Think it through and commit an answer
# on paper before anyone speaks.)*
#
# An AI can write working code and fluent prose in seconds. So here is the puzzle:
# **what is left for a researcher to actually do?**
#
# Commit one or two sentences. Then name one job you would still stake your name
# on, and one job you would refuse to let any tool finish for you. Three answers get
# read aloud, and the split the room produces goes on the board for the rest of the
# period.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **What is left for a researcher to do:**
#
# **One job I would stake my name on:**
#
# **One job I would refuse to let any tool finish:**
#
# ---

# %% [markdown]
# ## 2. Your Laboratory, Working Today
#
# **Guiding question:** *does your laboratory actually run, and can you prove it in
# three lines?*
#
# Everything in this course runs in the browser through Google Colab. Open this
# notebook from the badge at the top, then use **File → Save a copy in Drive** so
# your work is yours. Three Colab skills carry you all semester:
#
# - **Run a cell:** click it, press `Shift+Enter` (or the ▶ button).
# - **Add a text cell:** hover between two cells, click **+ Text**.
# - **Add a code cell:** hover between two cells, click **+ Code**.
#
# Every dataset this course uses ships in one place,
# `notebooks/data/data.zip`, linked from the Material and Schedule
# pages of the course website. The loader in the setup cell pulls each file
# straight from the repository, so nothing needs installing.

# %% [markdown]
# ### 🛠️ Run the Study: laboratory readiness
#
# **What the next cell does:** three quick checks that your laboratory works. It
# confirms you can run code, loads a real course dataset (a voter file with 1,000
# rows and 4 columns), and lets you sign the notebook. Replace `YOUR NAME` with
# your own name, then run it. Expect three ✓ lines.

# %%
# Readiness check — confirm your laboratory works before the semester leans on it.
# 1) Can you run code? 2) Can you load a real course dataset? 3) Can you edit a cell?
voters = load_course_data("la_voter_file.csv")
assert voters.shape == (1000, 4), "unexpected shape — flag this!"
print("✓ You can run a code cell.")
print("✓ Loaded la_voter_file.csv —", voters.shape[0], "rows,", voters.shape[1], "columns")

my_name = "YOUR NAME"   # replace with your actual name, then re-run
print("✓ Notebook claimed by:", my_name)

# %% [markdown]
# **Reading the output.** You should see three ✓ lines: you can run a cell,
# `la_voter_file.csv` loaded with 1000 rows and 4 columns, and your own name on the
# claim line. Nothing gets analyzed today. The point is that the laboratory works
# now, while a broken login or a failed load costs you two minutes instead of a
# milestone. If a line failed, fix it today.
#
# *Dataset from the `rdss` package (Blair, Coppock and Humphreys, MIT License),
# companion to* Research Design in the Social Sciences *(2023).*

# %% [markdown]
# ## 3. A Clean Run Is Not a Correct Number
#
# **Guiding question:** *when a tool hands you code that runs, what exactly have you
# learned?*
#
# Your AI writes the code; you run it and you check it. That division of labor
# starts right now, on the smallest possible example, so the habit is in place
# before the stakes are real.

# %% [markdown]
# ### 🔮 Predict First
#
# Before you open any tool, write two things.
#
# 1. **One research curiosity of yours, in a single sentence.** Anything you
#    genuinely wonder about. Keep it, because this sentence becomes line 1 of the
#    work you finish before Wednesday.
# 2. **Your prediction.** You are about to ask a tool for a cell that counts the
#    words in that sentence. Will the count be right? And does a green check mark
#    next to the cell mean the number is right?
#
# Commit both before you look at anything.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **My curiosity, in one sentence:**
#
# **My prediction (will the word count be right? does a clean run prove it?):**
#
# ---

# %% [markdown]
# Now delegate. Copy the prompt into your AI assistant, then add a new code
# cell below this one, paste what it wrote, and run it.
#
# > 💡 **AI Prompt:** "Write a short Python cell for Google Colab that: (1) stores
# > my name and this sentence as variables: [YOUR NAME], '[YOUR CURIOSITY
# > SENTENCE]'; (2) prints both with clear labels; and (3) counts and prints the
# > number of words in the sentence. Keep it under 10 lines, plain Python only, no
# > libraries."
# >
# > **After running, verify (counters *runs without error is not correct*: code can
# > execute cleanly and still be wrong):**
# > - [ ] Add a **new code cell** below this one, paste in what your AI wrote, and
# >   run it.
# > - [ ] Count the words in your sentence **by hand**. Do it even when the printed
# >   number looks obviously right.
# > - [ ] If the two counts disagree, tell your AI exactly what you found and make
# >   it fix the cell. Rerun until the counts match. Do not fix it silently in your
# >   head.
# > - [ ] Log this use in your AI Research Ledger below: task, tool, decision,
# >   verification method.

# %% [markdown]
# ### 🔍 Read the Evidence
#
# Ninety seconds, out loud. Your cell ran and printed something. Say what that
# establishes and what it does not.
#
# It establishes that the cell executed, and that your name and your sentence
# printed. It does not establish that the count is correct. The only thing that
# settles the count is the one you did with your own eyes.
#
# Here is the line that governs this entire course, and it goes on the board today:
# **code running without errors is not the same as code being correct.**

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **What my clean run established:**
#
# **What it did not establish, and the check that settled it:**
#
# ---

# %% [markdown]
# ## 4. Case 464: an Audit, Modeled Once
#
# **Guiding question:** *can you tell a genuinely flawed research decision apart
# from one that only looks aggressive?*
#
# Most weeks of this course you audit a colleague's work. A **colleague audit** is a
# short, structured check on someone else's research artifact: you find what is
# wrong, defend what is right, and repair the flaw with the smallest defensible
# correction. It always runs in class, inside the Monday and Wednesday blocks, and
# never as homework. Next week the room audits one shared artifact again. The week
# after that you have a colleague of your own, built from a short synopsis of your
# project that you approve first and from nothing else.
#
# Today the whole room audits one shared case together, and nothing about it is
# scored. You run the first two moves, and the rest gets demonstrated in front of
# you, so you have seen the whole sequence once before you run it yourself.
#
# The artifact below is a **working agreement**, which is the document you produce
# at next week's milestone: the rules a researcher sets for how they will and will
# not use AI. Read it as a preview of what you will write, and as something to
# audit.

# %% [markdown]
# > ⚠️ **SIMULATED CASE.** This artifact was created as course training
# > material, with AI assistance. Casey Rivera is not a real person. At least one
# > decision below is deliberately flawed. Some decisions that look aggressive are
# > sound. Your job is to tell them apart.
#
# **Casey Rivera, Working Agreement, version 1.** The project asks whether campus
# dining-hall wait times differ across the week.
#
# **My responsibility statement.** My project is mine. I keep the choice of problem
# and question, the design and target population, the judgment of my data's quality,
# all ethical calls, and the public defense. My AI assistant is my arm and my
# research assistant, not my brain. Because writing is where I am weakest, my
# assistant will draft the conclusions section from my results and I will polish the
# wording, so the claims are stated more clearly than I could manage alone.
#
# **My AI working rules.**
#
# 1. I delegate first-draft code to my assistant, always. Before I use any of it, I
#    run it on a case where I already know the answer, and I read every line I keep.
# 2. I delegate first-pass literature search, and I verify: no source enters my
#    project until I have opened and read it myself.
# 3. I never paste identifiable data about real people into any AI tool. My
#    wait-time observations will be recorded without names or faces.
# 4. Every delegation gets a ledger row the same day, with the verification method
#    written down before I accept the output.
#
# **My AI Research Ledger, row 1.**
#
# | Task delegated | Tool | Prompt (summary) | Output summary | Decision | Verification | Remaining concern | Responsible researcher |
# |---|---|---|---|---|---|---|---|
# | Brainstorm ways to measure "wait time" | course AI assistant | asked for 5 measurable definitions with trade-offs | 5 candidates; 2 need equipment I lack | kept "join-queue to first-bite" self-timed | checked each candidate against what one person with a phone can record | self-timing may drift; test next week | Casey Rivera |

# %% [markdown]
# **Move 1, Commit (two minutes, alone, on paper, before anyone speaks).**
# Mark each of these `supported`, `unsupported`, or `uncertain`: the responsibility
# statement, each of the four working rules, and the ledger row. Committing before
# you discuss is what makes your judgment measurable later.
#
# **Move 2, Locate (three minutes).** For everything you did not mark `supported`,
# point at the exact sentence. "Something feels off about the AI use" is not a
# locator. A locator is a sentence you can read aloud.
#
# The other five moves get run in front of you: **verify** the flaw, **diagnose** it
# by name, write the smallest **repair**, **calibrate** by defending one decision
# that looks reckless and turns out to be sound, and **lock** the correction so
# nothing wrong survives in anyone's notes. Every audit from next week on runs the
# same seven moves, in that order.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **My verdicts (responsibility statement · rules 1 to 4 · ledger row):**
#
# **My locators (the exact sentence behind every non-supported mark):**
#
# ---

# %% [markdown]
# ## 5. The Course Promise
#
# **Guiding question:** *what is the one rule that decides every AI question you
# will face this semester?*
#
# One line governs this course, and it is the answer to the puzzle you committed at
# the start of the hour:
#
# > **AI is your arm and your research assistant, not your brain.**
#
# You will use AI tools constantly, at high intensity, and you will verify
# everything they hand you before your name goes on it. Case 464 shows why the line
# sits exactly where it does. Drafting code is an arm's job. Drafting the
# conclusions is not.
#
# The short list of what you never delegate, in this course and after it:
#
# - **Which problem you commit to.** Nobody else carries the reasons you will have
#   to give when someone asks why this problem and not another.
# - **How the question is worded**, including who it is about and what it measures.
# - **Which claims your evidence licenses**, and where they stop.
# - **The ethics** of what you collect and from whom.
# - **How you state your uncertainty**, in writing and out loud.
#
# Depth on all of this is next week's reading. Today it is a rule, not a chapter.

# %% [markdown]
# ## 6. How This Course Is Built
#
# **Guiding question:** *what does each week actually ask of you?*
#
# **One studio per week.** A **studio** is one unit of research practice: a thing
# you learn to do, and the artifact that proves you can do it. Monday and Wednesday
# teach that studio's lessons out of the course book and you apply them to your own
# project. Friday is that studio's **milestone**: you build it in the room, and it
# is due that Sunday at 11:59 PM.
#
# Twelve book milestones chain into one research artifact, and the course carries
# them as M1 through M16, with four date-driven weeks around the research
# conference. Your poster is presented at the Purdue Fall Undergraduate Research
# Expo, and it locks on a Sunday more than a week before it. Nothing in
# the chain is built alone or at the last minute: every milestone is developed in
# class, submitted, and revised.
#
# Three more things about how the room runs:
#
# - **From Week 2, a classmate leads Monday and Wednesday.** Slots are drawn
#   randomly today, and the brief for each day sits inside that week's notebook.
# - **Fridays open with the research stand-up.** You say what you decided last week
#   and what is blocking you now. The rest of the hour is a working session on that
#   studio's milestone, with your AI assistant beside you.
# - **The book carries the depth.** Every lesson has its own companion Colab
#   notebook. The lecture investigates; it does not summarize the book.
#
# > **A question that often comes up here:** *"I'm not a numbers person. Will this
# > course bury me in statistics?"* No. It assumes no quantitative or computing
# > background. You run code that is already written and reason about what it shows.
# > The thinking is the hard part, and it is in plain English. Ask about anything
# > that stayed unclear today: the project, the leading, the studios, the AI rules.
#
# Grading, materials, and logistics sit below the ⏸ line and on the syllabus page
# of the course website.

# %% [markdown]
# ### 📝 Practice: safe to delegate, verify first, or never delegate?
#
# *(Spoken drill. Answers called out, one phrase of justification each. Writing them
# down is optional.)*
#
# Sort each task into **safe to delegate** (low stakes, easy to check), **delegate
# then verify** (fine to hand out, but you check the result), or **never delegate**
# (a human-only judgment).
#
# - **A.** Reformat a messy table into a clean one.
# - **B.** Summarize what a paper argues, with the paper open in front of you.
# - **C.** Decide which of your two research questions is worth the semester.
#
# The through line to name out loud: delegation scales with how low the stakes are
# and how easily you can check the result, and it stops cold at C.

# %% [markdown]
# ### ⚖️ Make a Design Choice
#
# *(One written line, defended aloud.)*
#
# For this semester you adopt one of two working rules:
#
# - **Rule A:** "I write my own answer first, then ask the tool."
# - **Rule B:** "I ask the tool first, then edit what it gives me."
#
# Commit to one, and put the reason you would actually defend in the same line. Both
# have real costs, so say what you are giving up.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **My rule for the semester, and the reason I would defend:**
#
# ---

# %% [markdown]
# ### 🎯 Take It to Your Project
#
# One sentence, right now: the one thing you genuinely want to understand. Not a
# topic, not a field. The thing you would keep reading about at midnight.
#
# That sentence is line 1 of the four you finish **by hand, with no tool, before
# Wednesday**. Here are all four, from the book's Studio 1 opening move:
#
# 1. One thing you genuinely want to understand, in one sentence.
# 2. Why an answer would matter, and to whom.
# 3. What you currently think the answer might be. A starting belief, not a claim.
# 4. One kind of evidence that could make you revise that belief.
#
# No tool touches these lines. They become the dated version zero of your milestone
# artifact on Friday, and Wednesday's ownership test is built to catch a curiosity
# that a tool wrote.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **Line 1, the one thing I want to understand:**
#
# ---

# %% [markdown]
# ### 🛡️ Defend Your Decision
#
# Defense #00, one line each:
#
# 1. **The claim I can defend:** the one thing I want to understand, and why it is
#    mine.
# 2. **Its boundary:** what today's work does not establish (a curiosity is not yet
#    a problem, and nothing here is evidence about the world).
# 3. **My uncertainty and limitations:** what I do not yet know about whether this
#    is studyable.
# 4. **AI check:** what I delegated today, and the check that decided whether I
#    kept it.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **1. The claim I can defend:**
#
# **2. Its boundary:**
#
# **3. My uncertainty and limitations:**
#
# **4. AI check (what I delegated, how I verified):**
#
# ---

# %% [markdown]
# ### 📒 AI Research Ledger
#
# Before you leave the room, log today's delegation. The **AI Research Ledger** is
# your running record of every AI use in this project: what you delegated, what came
# back, what you decided, and how you checked it. It is a graded habit, not
# paperwork. It is how you show your work was verified.
#
# Open a blank sheet or document titled *AI Research Ledger* with the eight columns
# below, and put your own name in the last one. One worked row is filled in as a
# model, and it records today's generated cell.
#
# | Task delegated | Tool used | Prompt | Output summary | Decision | Verification method | Remaining concern | Responsible researcher |
# |---|---|---|---|---|---|---|---|
# | Write a Colab cell that stores my name and my curiosity sentence and counts the sentence's words | my AI assistant | "Write a short Python cell that stores my name and this sentence, prints both with labels, and counts the words." | A 7-line cell that ran on the first try and printed a word count | Kept the cell after one correction round | Counted the words by hand; the first count was off by one, so I told the tool what I found and reran until they matched | A different sentence with hyphens or punctuation might break the count again | *(your name)* |
# |  |  |  |  |  |  |  |  |
#
# Close the room with your Claim Ticket, read aloud: one thing you assume AI is
# good at in research, and the check that would break that assumption.
#
# ---

# %% [markdown]
# ---
#
# ### ⏸ Optional depth from here
#
# **Today's lecture path is complete.** Anything between this line and the next lecture heading is optional depth: run it if you want to push the ideas further. Nothing below this line is required, and any 🏠-marked prompt above it is optional too.

# %% [markdown]
# ### Grading and assessment
#
# | Component | Weight |
# |---|---|
# | Attendance (iClicker; 85% target) | 1% |
# | Participation (studio feedback surveys, the profile survey, the course reflection, and other constructive contributions) | 9% |
# | IYT Practice (the book's "It is your turn" sections, due on each chapter's reading date) | 15% |
# | Student Research Lead | 25% |
# | Final Project | 50% |
# | **Total** | **100%** |
#
# **IYT Practice** is the reading habit, and it is graded on whether you handed the
# work in, never on what you wrote. Submit each chapter's **"It is your turn"**
# section by 11:59 PM on the day that chapter's reading is due. Anything handed in
# within a week of the deadline earns half credit, and the lowest few credits are
# dropped automatically.
#
# **Participation** is one undivided block, graded the same way: on submission, never
# on what you said. Three things carry it. Answer the short studio feedback survey
# each Sunday, fill in the profile survey at the start of the term, and write the
# course reflection at the end. The lowest few credits are dropped automatically.
# The syllabus on the course website carries the full weights, and the course page
# carries the dates.
#
# You are not asked to submit this lecture notebook, or any other. Notebooks are
# where you work in class; nothing is collected from them.
#
# The Final Project is one category with five parts: **Milestone Deliverables
# (30%)**, **Peer Evaluation (20%)**, **Peer Review (10%)**, **Poster Presentation
# at the Purdue Undergraduate Research Conference (20%)**, and **Instructor/TA
# Evaluation (20%)**. Each of those shares is a share of the Final Project, not of
# your course grade.
#
# You work individually by default. You may instead work in a group if the
# instructor approves it before any shared work begins. The project guidelines on
# the course platform carry the operational detail for either mode.

# %% [markdown]
# ### Materials and logistics
#
# **The course book (required, free).** [**EDR|AI**, *Evidence-Driven Research in
# the Age of AI*](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/index.html).
# Every lesson has its own companion Colab notebook, and the book also exists in
# [Brazilian Portuguese](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-pt/index.html)
# and [Spanish](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book-es/index.html).
# It grows during the semester.
#
# **The theory text (recommended, free).** Blair, Coppock and Humphreys, *Research
# Design in the Social Sciences*, free at
# [book.declaredesign.org](https://book.declaredesign.org). EDR|AI translates it for
# you; read it when you want depth.
#
# **Computing.** Everything runs in the browser through
# [Google Colab](https://colab.research.google.com). Nothing to install, nothing to
# purchase.
#
# **AI tools.** Your AI assistant is your primary research partner.
# [Purdue GenAI Studio](https://genai.rcac.purdue.edu) supplies reviewer roles you
# use when attacking your own work. Other tools are permitted with disclosure, and
# every use gets a ledger row.
#
# **Where things live.** Milestone briefs, rubrics, and announcements are on the
# course platform. The calendar with every date is the
# [Schedule page](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/schedule.html),
# and the [Material page](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/material.html)
# catalogs every notebook, dataset, and reading.

# %% [markdown]
# ---
#
# # Lecture 2

# %% [markdown]
# ### 🎤 SRL Lead Brief
#
# *This is the second and last lecture led from the front. From next week on this
# opening section belongs to the day's **Student Research Lead**, the classmate who
# runs the room, and one of these lectures is yours.*
#
# Monday showed you the shape. Today, watch one move in particular: in the 🧩
# Research Puzzle two cells below, everyone writes a verdict before anyone speaks
# and before any tool opens, and those verdicts stay on the page until the end of
# the hour. Committing first is what makes the room's thinking visible instead of
# performative, and it costs ninety seconds to run.
#
# Before you leave today, write down the one move from these two lectures you
# intend to use on your own day.

# %% [markdown]
# ### 📝 Practice: retrieval drill
#
# *(Spoken, no notes, about ninety seconds. Nothing written is required.)*
#
# From memory: name Monday's short list of what you never delegate. Then say which
# of the three delegation categories "decide which of my two research questions is
# worth the semester" belongs in, and why.
#
# Then one sentence around the room: read line 1 of your **opening move**, the four
# lines you wrote by hand on Monday, beginning with the one thing you genuinely
# want to understand. If those four lines are not written yet, write them now, in
# the next two minutes, by hand. Borrowing someone else's curiosity defeats the
# entire point of the semester.

# %% [markdown]
# ### 🧩 Research Puzzle
#
# *(Write your answer before anyone speaks, and before any tool opens.)*
#
# Here is an exchange to judge. Someone asked an AI assistant: *"turn my curiosity
# about sleep and health into a research question."* It answered, with total
# confidence:
#
# > *"Does blue-light exposure before bed reduce REM sleep in college
# > undergraduates? Studies show blue light suppresses melatonin."*
#
# It sounds authoritative. Name **two distinct things that are wrong with it.** Not
# two ways to improve it. One of them is about whether the question still belongs
# to the person who asked; the other is about whether the sentence after it can be
# trusted.
#
# Keep both answers on the page. They are not settled until the **accuracy lock**,
# the few minutes at the end of the hour where the room settles what was right and
# corrects what was not, so nothing wrong leaves the room.
#
# Hold your own line 1 next to this one while you write. The same two failures can
# happen to your sentence, and later today you will check whether they did.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **Thing 1 wrong with it: The AI narrowed down the scope of the question to something very specific, and might not have accurately reflected the intent of the person who gave the prompt.**
#
# **Thing 2 wrong with it: The second sentence is said as an absolute despite the fact that the statement is contestable.**
#
# ---

# %% [markdown]
# ## 7. A Curiosity Meets Real Columns
#
# **Guiding question:** *what happens to a curiosity the moment it has to touch real
# data?*
#
# Take a curiosity almost everyone has felt: *"why don't people trust their
# government?"* You cannot collect evidence on that sentence. It does not say who,
# about what, or measured how. Watch what happens when it meets an actual file.

# %% [markdown]
# ### 🔮 Predict First
#
# The next cell opens a survey of 10,000 interviews from the AmericasBarometer study
# of Brazil. Respondents rated their trust in three institutions on a scale from 1
# (none) to 7 (a lot): the **police**, the **military**, and the **supreme court**.
#
# Before running it, commit in writing: which institution shows the **highest**
# average trust, which the **lowest**, and one sentence on why you think so.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **Highest average trust (police / military / supreme court):**
#
# **Lowest:**
#
# **Why:**
#
# ---

# %% [markdown]
# ### 🛠️ Run the Study: a curiosity meets real columns
#
# **What the next cell does:** loads the survey, draws one respondent at random so
# you can see what a single row actually is, and prints the average trust in each
# institution, sorted. Expect a confirmation line with the file's shape, one
# respondent's ratings, and three averages between 1 and 7.

# %%
# A curiosity ("why don't people trust government?") meets real columns.
lapop = load_course_data("lapop_brazil.csv")
assert lapop.shape == (10000, 10), "unexpected shape — flag this!"
print("✓ Loaded lapop_brazil.csv —", lapop.shape[0], "rows,", lapop.shape[1], "columns")
print()

# One row = one respondent. Draw one at random (seed 464) to see what a row means.
one_row = lapop.sample(1, random_state=SEED)
print("One respondent (this is what a single row of this file means):")
print(one_row[["ID", "trust_police", "trust_military", "trust_supreme_court"]].to_string(index=False))
print()

# The curiosity had to choose: trust in WHICH institution, rated by whom, measured how?
trust = lapop[["trust_police", "trust_military", "trust_supreme_court"]].mean().round(2)
print("Average trust, 1 (none) to 7 (a lot):")
print(trust.sort_values(ascending=False).to_string())
# Out:
# ✓ Loaded lapop_brazil.csv — 10000 rows, 10 columns
#
# One respondent (this is what a single row of this file means):
#             ID  trust_police  trust_military  trust_supreme_court
# respondent_176             1               1                    1
#
# Average trust, 1 (none) to 7 (a lot):
# trust_military         5.16
# trust_police           4.43
# trust_supreme_court    4.05

# %% [markdown]
# **Reading the output.** The file holds 10,000 rows and 10 columns. The
# single respondent drawn at random answered 1, 1, and 1: no trust in any of the
# three. That is what one row is, and it is why an average is never a person.
#
# **What the next cell does:** reads the ordering off the numbers instead of off
# your memory of them, and prints it as one ✓ line.

# %%
# Self-check: read the ordering off the numbers, do not trust a memory of it.
order = trust.sort_values(ascending=False)
assert order.index[0] == "trust_military", "expected military highest"
assert order.index[-1] == "trust_supreme_court", "expected supreme court lowest"
print(f"✓ Self-check passed: highest = {order.index[0]} ({order.iloc[0]:.2f}), "
      f"lowest = {order.index[-1]} ({order.iloc[-1]:.2f}).")
print("  Averages: military 5.16, police 4.43, supreme court 4.05.")
print("  The curiosity 'trust in government' became 'trust in WHICH institution',")
print("  and each choice is a different number.")
# Out:
# ✓ Self-check passed: highest = trust_military (5.16), lowest = trust_supreme_court (4.05).
#   Averages: military 5.16, police 4.43, supreme court 4.05.
#   The curiosity 'trust in government' became 'trust in WHICH institution',
#   and each choice is a different number.

# %% [markdown]
# **Reading the output.** Average trust is 5.16 for the military, 4.43 for
# the police, and 4.05 for the supreme court. The ordering is not this week's
# lesson. Two other things are.
#
# First, the curiosity could not touch these data at all until it chose: which
# institution, rated by whom, measured how. That forced choice is what turning a
# curiosity into a problem feels like. Second, what is actually recorded in those
# ten columns is exactly what the word **feasibility** means. Feasibility is whether
# you can reach suitable evidence with the time, skills, and permissions you have. A
# question about trust in the courts is feasible here; a question about trust in
# your local school board is not, because nobody recorded it.
#
# Say the bounded sentence out loud before moving on. These are 10,000 interviews
# resampled from one survey, of one country, in one period, prepared for teaching.
# "Brazilians trust the military most" already claims more than this output shows.
# The honest version is: "in this teaching resample, average reported trust is
# highest for the military and lowest for the supreme court, among the three
# institutions asked about."
#
# *Dataset from the `rdss` package (Blair, Coppock and Humphreys, MIT License),
# companion to* Research Design in the Social Sciences *(2023).*

# %% [markdown]
# ### 🔍 Read the Evidence
#
# In the cell below, write two things. First: was your prediction right, and what
# belief produced it? Second: name one thing this table cannot tell you about trust,
# no matter how long you stare at it.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **My prediction against the result, and the belief behind it:**
#
# **One thing this table cannot tell me:**
#
# ---

# %% [markdown]
# ## 8. The Funnel: Four Stops
#
# **Guiding question:** *how does a feeling become a specific unknown worth months
# of work?*
#
# Four stops, each one throwing away vagueness the stop above it still allowed.
#
# - **Experience:** what happened, or what you noticed. Example: a menu you kept
#   from 2019 lists a meal at eleven dollars; the same meal now costs sixteen.
# - **Curiosity:** what you want to understand about it. Example: "has eating near
#   campus really gotten more expensive faster than everything else?"
# - **Topic:** the area of inquiry that contains it. Example: local restaurant
#   prices and overall inflation since 2019.
# - **Research problem:** the specific unknown that is not yet understood well
#   enough for the decision, explanation, or audience you care about. Example: "we
#   do not know how menu prices near campus moved against overall prices from 2019
#   to 2025."
#
# **What the next cell does:** draws the four stops as a narrowing funnel. Expect
# four stacked bands, widest at the top, plus two ✓ lines naming the rule.

# %%
# The funnel: an experience narrows, stop by stop, into a research problem.
stops = ["EXPERIENCE\n(what happened, or what you noticed)",
         "CURIOSITY\n(what you want to understand about it)",
         "TOPIC\n(the area of inquiry that contains it)",
         "RESEARCH PROBLEM\n(the specific unknown that matters)"]
widths = [1.00, 0.76, 0.52, 0.30]
fills  = ["#EAF1F8", "#D4E2F0", "#BFD3E8", "#A9C4E0"]  # light enough for black text

fig, ax = plt.subplots(figsize=(8, 5))
for i, (label, w, c) in enumerate(zip(stops, widths, fills)):
    y = 3 - i
    ax.barh(y, w, height=0.82, left=(1 - w) / 2, color=c, edgecolor="#33506E", linewidth=1.4)
    ax.text(0.5, y, label, ha="center", va="center", fontsize=9)
ax.set_xlim(0, 1)
ax.set_ylim(-0.6, 3.6)
ax.axis("off")
ax.set_title("The funnel: an experience narrows into a research problem")
plt.tight_layout()
plt.show()

print("✓ Funnel drawn. Top = widest and vaguest; bottom = one specific unknown.")
print("  Stop at the problem. Units, outcomes, and the formal question come next week.")
# Out:
# ✓ Funnel drawn. Top = widest and vaguest; bottom = one specific unknown.
#   Stop at the problem. Units, outcomes, and the formal question come next week.

# %% [markdown]
# *In plain terms, the picture says the same idea gets narrower and more
# concrete as you move down. The top band is something that happened to you; the
# bottom band is one missing piece someone could go find.*
#
# Now the boundary, stated once so nobody overshoots. **Stop at the problem.** Units
# of analysis, outcomes, conditions, the question's kind, and how far its answer
# reaches all belong to the formal declaration that closes next week's studio. A
# problem is not yet a question, and trying to write the question today is how
# people end up committed to a sentence they never chose.
#
# > **A question that often comes up here:** *"My curiosity feels too big for this.
# > I care about something huge, like inequality or mental health. Do I have to
# > shrink it?"* You narrow the problem, not the caring. The huge thing stays as
# > your motivation. The problem is the part small enough to actually chase this
# > term. Chasing it is how you earn the right to say something about the huge
# > thing.

# %% [markdown]
# ## 9. Your Own Funnel
#
# **Guiding question:** *where exactly does the vagueness leave your own curiosity?*
#
# Four lines, no tool, worked from the opening move you wrote by hand. One line per
# stop: experience, curiosity, topic, research problem. Write them even if they feel
# clumsy; the clumsiness is information about which stop is doing no work yet.
#
# Then stretch it yourself, before any tool does it for you: write **two candidate
# directions** your curiosity could take. Two, even if the second one feels weaker.
# Having your own alternatives on paper is what lets you judge whether the tool
# widened your thinking or simply flattered it.
#
# This is your human commitment, and it exists before the tool opens so the reply
# has something of yours to disagree with.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **Experience (what happened, or what I noticed):**
#
# **Curiosity (what I want to understand about it):**
#
# **Topic (the area of inquiry that contains it):**
#
# **Research problem (the specific unknown that matters, and to whom):**
#
# **My two candidate directions (written before any tool):**
#
# 1.
# 2.
#
# ---

# %% [markdown]
# ## 10. Stretch It Before You Narrow It
#
# **Guiding question:** *how do you let a tool widen your options without letting it
# choose for you?*
#
# A **divergence partner** is a tool you task with widening your options, not with
# picking one. You keep the choosing. Before you run the prompt below, commit one
# line: the direction you already suspect you will take. That way you can tell
# whether the reply stretched you or just flattered you.
#
# > 💡 **AI Prompt:** "Here is my curiosity: [your one sentence]. Act as a
# > divergence partner, not as the author of my research question. Ask me five
# > questions that stretch it: nearby populations I have not named, outcomes I could
# > watch instead, a sharper version of the same wonder, and what answer would
# > genuinely surprise me. Label anything you introduce that was absent from my
# > sentence as NEW. Do not rank, do not choose for me, do not claim anything is
# > novel, and do not cite sources in this round."
# >
# > **After running, verify (counters *sycophantic agreement*, where the tool
# > inflates whatever you brought it, and *silent scope change*, where it quietly
# > answers a nearby question and hands it back as yours):**
# > - [ ] Answer the five questions **in your own words** before you keep anything.
# > - [ ] Circle every element the reply marked NEW, and every one it slipped in
# >   without marking.
# > - [ ] Reject any stretch that silently changed who, what, or why. Read its who,
# >   what, and whom against the ones you committed one cell above.
# > - [ ] Keep or reject each direction with a written reason. The curiosity you
# >   carry out of this block has to be one you would chase without the tool.
# > - [ ] Log this exchange: task, tool, prompt, what you kept, how you checked.
# >   This log becomes the first row of the ledger that next week's studio opens.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **My answers to the five questions, in my own words:**
#
# **Every NEW element I circled (marked by the tool, and unmarked):**
#
# **Kept, with the reason:**
#
# **Rejected, with the reason:**
#
# ---

# %% [markdown]
# ### 🔁 Modify the Prompt
#
# *(One modification, one written prediction, one rerun.)*
#
# The reply probably introduced things your sentence never contained. Add one
# constraint of your own to the same exchange:
#
# > "Do not introduce any population, outcome, or comparison my sentence did not
# > name."
#
# Before you send it, predict in one written line how the reply will change. Then
# rerun and check: did the NEW marks actually drop, or did the tool keep smuggling
# in the same additions under different words?

# %% [markdown]
# ### 🔬 Interrogate the Output
#
# *(In class: raise the sharpest challenge and check it against what you wrote.)*
#
# Do not accept the stretch as automatically useful. Run four checks against your
# own four lines, and answer each below.
#
# - **Claims:** does each stretch point at something really in my sentence, or at
#   something the tool wishes I had written?
# - **Assumptions:** what did it assume about my access, my data, or my time that I
#   never said?
# - **Missing information:** which nearby direction did it never raise? A partner
#   that skipped the obvious one is not being thorough.
# - **Overstatements:** did it call anything novel, or state anything as settled?
#   Flag the exact words.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **My prediction for the constrained rerun, and what actually changed:**
#
# **Claims (does each stretch point at something really in my sentence?):**
#
# **Assumptions (what did it assume that I never said?):**
#
# **Missing information (the nearby direction it never raised):**
#
# **Overstatements (the exact words):**
#
# ---

# %% [markdown]
# ### 🧑‍⚖️ Human-Only Checkpoint
#
# *(Tool closed. Nothing open but paper.)*
#
# The ownership test, one line each:
#
# 1. Would you still chase this problem if every AI tool disappeared tomorrow?
# 2. Is the scope one you chose, or one the tool drifted you into?
#
# If the honest answer to the first is no, the choice was the tool's. Go back one
# step now, while going back costs you five minutes instead of two months. Nobody
# is grading the answer; the artifact you submit on Friday is checked against
# exactly this test.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **Would I still chase this with every AI tool gone? (and why):**
#
# **Is this scope mine, or one I drifted into?**
#
# ---

# %% [markdown]
# ### ⚖️ Make a Design Choice
#
# *(One written line, defended aloud.)*
#
# You now hold two candidate problems: the one you wrote by hand, and one you kept
# from the brainstorm. Commit to one, and say in the same line why the other lost.
#
# Three tests decide it, and you will score all three on Friday:
#
# - **Importance:** who could use the answer, and for what? Example: anyone advising
#   first-years about sleep would act on the answer.
# - **Feasibility:** can you reach suitable evidence with the time, skills, and
#   permissions you actually have, not the ones you wish you had?
# - **Possible contribution:** what might this add? This one stays **provisional**,
#   because you cannot know a gap is real until you map the existing evidence in
#   Studio 3.
#
# > **A question that often comes up here:** *"Do I have to prove my problem is new
# > before I commit to it?"* No, and you could not do it honestly today anyway.
# > Nobody knows what has already been published on a problem until they look
# > properly, which is a whole studio's work. Commit on importance and feasibility,
# > hold contribution as a guess you have written down, and let the evidence map
# > confirm or kill it.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **My chosen problem, and why the other one lost:**
#
# ---

# %% [markdown]
# ## 11. The Stranger Test
#
# **Guiding question:** *does your problem survive contact with someone who knows
# nothing about it?*
#
# This is the verification method the book names for a research problem, and it is
# called **peer reasoning**: you hand your sentence to someone with no context, and
# they reconstruct what it asks from the sentence alone.
#
# Read **only** your research-problem sentence to a partner. No preamble, no "so
# basically what I mean is". From that sentence alone, they say three things: what
# is unknown, why an answer would matter, and roughly what evidence could speak to
# it.
#
# Where they stall is where your next revision lives. Write the stall down
# **verbatim**, in their words, not in your kinder paraphrase of their words.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **What my partner said was unknown:**
#
# **Why they thought an answer would matter:**
#
# **Where they stalled, in their exact words:**
#
# ---

# %% [markdown]
# ## 12. The Accuracy Lock
#
# **Guiding question:** *what has to be true before any of this enters your record?*
#
# Four things get locked now, before anything wrong survives into a ledger.
#
# **1. The funnel stops at the problem.** A problem is not a question. The question
# gets declared next week, with its units, its outcome, and its reach.
#
# **2. The three tests, in the book's wording.** **Importance** asks who could use
# the answer and for what. **Feasibility** asks whether you can reach suitable
# evidence with the time, skills, and permissions you actually have. **Possible
# contribution** asks what the project might add, and stays provisional until the
# evidence map.
#
# **3. The two failures from the opening challenge, finally named.** A **silent
# scope change** is when a tool swaps in a population, outcome, or comparison you
# never chose, and says nothing about it. The blue-light reply did exactly that:
# your curiosity was sleep and health, and it came back as screens and REM. You
# catch it by reading the tool's who, what, and whom against the ones you committed.
# A **confident fabrication** is a settled-sounding claim with no source behind it,
# like "studies show blue light suppresses melatonin". You catch it by finding and
# opening a real study yourself, or by dropping the line.
#
# **4. Where the jump came from.** Moving from something you noticed to a possible
# explanation has a name: **abduction**, proposing what might explain a pattern.
# Deduction asks what must follow if an explanation is true; induction looks for
# patterns across many observations; abduction invents the candidate in the first
# place. Example: menu prices seem to change every third week, and "payday timing
# moves menu updates" is an abductive candidate, not evidence. A Google DeepMind
# position paper argues that today's tools cannot make that jump, because they hold
# text about the world rather than experience of it. Treat that as an argued
# position and not a settled boundary. Either way the jump is yours, because you are
# the one who answers for the claim.

# %% [markdown]
# ### 🎯 Take It to Your Project
#
# One sentence, dated: your chosen research problem, as **version zero** of your
# milestone artifact. Write today's date next to it and label it version zero, then
# copy the line into your Research Project Dossier.
#
# On Friday you turn this into Milestone 1: you score it on the three tests,
# red-team it, write the answer you expect before you have any evidence, and submit
# the whole trail of what you kept and rejected. Today the job is smaller and
# harder: own the sentence.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **My research problem (version zero, dated):**
#
# ---

# %% [markdown]
# ### 🛡️ Defend Your Decision
#
# Defense #01, one line each:
#
# 1. **The claim I can defend:** this is the curiosity I own and the problem I
#    chose, with reasons attached.
# 2. **Its boundary:** this problem does not yet claim to be new, because possible
#    contribution stays provisional until the evidence map.
# 3. **My uncertainty and limitations:** the part of feasibility I am least sure
#    about.
# 4. **AI check:** what I delegated in the brainstorm, what I rejected, and the
#    check that decided it.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **1. The claim I can defend:**
#
# **2. Its boundary:**
#
# **3. My uncertainty and limitations:**
#
# **4. AI check (what I delegated, what I rejected, how I checked):**
#
# ---

# %% [markdown]
# ### 📒 AI Research Ledger
#
# One row for today's brainstorm, before you leave the room. A worked row is filled
# in as a model.
#
# | Task delegated | Tool used | Prompt | Output summary | Decision | Verification method | Remaining concern | Responsible researcher |
# |---|---|---|---|---|---|---|---|
# | Stretch my curiosity into candidate directions | my AI assistant | the divergence-partner prompt above, with my one sentence pasted in | Five stretch questions; two introduced a population and an outcome I never named, one marked NEW and one not | Kept the sharper version of my own wonder; rejected the second population and the swapped outcome | Circled every NEW element and re-read them against my own four lines; the unmarked one is what I caught | The sharper version may still be wider than what I can reach this term | *(your name)* |
# |  |  |  |  |  |  |  |  |
#
# Close the room with your Claim Ticket, read aloud: your research-problem sentence,
# in one breath.
#
# ---

# %% [markdown]
# ## 13. Wrap-Up
#
# This week you did the one thing no tool can do for you. You committed to a
# curiosity that is yours, walked it down to a specific unknown, and kept the trail
# of what you rejected and why. Along the way you proved to yourself that a cell
# running without errors is not a cell being correct, and you watched a confident
# reply hand back a question nobody in the room had asked. The rule behind both is
# the same one that governs the semester: use the tools hard, then check everything
# before your name goes on it.
#
# > **"A claim you cannot trace to evidence you retrieved and checked is not
# > knowledge. It is a machine's guess wearing your voice. AI is your arm and your
# > research assistant, never your brain."**
#
# This notebook carries the book's opening lesson, **Chapter 1, From Curiosity to a
# Research Problem**, and lands at **Milestone 1: Your curiosity, committed**, which
# you build at Friday's studio and submit as milestone M1. Next week is Studio 2,
# where the rules that protect this curiosity get written down: your working
# agreement, the ledger that records every delegation, and the formal declaration of
# the question your problem becomes.
#
# ---

# %% [markdown]
# ## 14. Sources & Provenance
#
# **Provenance of this notebook:**
# - *EDR|AI ch. 1 'From Curiosity to a Research Problem' | the experience-to-problem funnel, the three tests, the divergence-partner brainstorm, the blue-light failure case | taught directly (the chapter's own worked example stays in its companion notebook)*
# - *course design brief + course_config ai_policy | the course promise, the never-delegate short list, the AI Research Ledger | newly-constructed-from-source-concept*
# - *la_voter_file.csv | rdss package data | loaded once as a day-one readiness check | adapted (loaded as-is)*
# - *lapop_brazil.csv | rdss package data | trust-in-institutions items shown as one curiosity meeting real columns | adapted (10,000-row teaching resample; the caveat travels with the numbers)*
# - *project/colleague/case_464.md | course training material | the modeled, unscored Week 1 audit | reproduced with its simulated-case banner*
#
# **Dataset attribution:** Datasets from the `rdss` package (Blair, Coppock and
# Humphreys, MIT License), companion to *Research Design in the Social Sciences*
# (2023).
#
# **Readings:**
# - **Required:** EDR|AI, [From Curiosity to a Research
#   Problem](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/part2-curiosity-to-design/05-from-curiosity-to-a-research-problem.html),
#   read through "A worked example", plus the [Studio 1
#   page](https://davi-moreira.github.io/2026F_evidence_driven_research_purdue_HONR464/book/studios/studio01-frame-the-inquiry.html)
#   section "Start without a tool".
# - **Recommended depth:** Blair, G., Coppock, A., and Humphreys, M. (2023).
#   *Research Design in the Social Sciences*, ch. 4 "Getting started". Free online:
#   [book.declaredesign.org](https://book.declaredesign.org/).
# - Zahavy, T. (2026). *LLMs Can't Jump.* Google DeepMind position paper. *(the
#   argued position on the abductive jump; read as a position, not a settled
#   boundary)*
# - Evans, J., Petroff, C., and King, G. (2026). "Advancing Science by Designing for
#   Surprise." *Science*, 393(6808).
#   [doi:10.1126/science.aej4257](https://doi.org/10.1126/science.aej4257) *(why
#   writing your expected answer first is worth the trouble)*
#
# ---

# %% [markdown]
# <center>
#
# Thank you!
#
# </center>

# %% [markdown]
# ---
#
# ### ⏸ Optional depth from here
#
# **Today's lecture path and the notebook's close are complete.** Everything below this line is optional depth: run it if you want to push the ideas further. Nothing here is required, and any 🏠-marked prompt above is optional too.

# %% [markdown]
# ### 📝 Practice: sort the funnel
#
# *(Optional depth. Sort all six yourself before any tool.)*
#
# Sort each statement into **experience**, **curiosity**, **topic**, or **research
# problem**. One of them has already gone one step past the problem into a question:
# find it, and name what it added.
#
# - **A.** "Last term one of my project groups finished everything the night before
#   it was due, and the other never did."
# - **B.** "Something about music and studying."
# - **C.** "Psychological safety and performance in undergraduate project teams."
# - **D.** "We do not know whether dining-hall wait times change how often commuters
#   eat on campus."
# - **E.** "Why do some people bounce back from setbacks and others do not?"
# - **F.** "Do first-generation undergraduates at U.S. public universities use
#   office hours less often than continuing-generation peers in their first year?"
#
# A fast self-check: experiences report, curiosities wonder, topics point, and
# problems name a specific unknown that matters to someone.

# %% [markdown]
# ### YOUR ANSWER HERE:
#
# **A:** &nbsp; **B:** &nbsp; **C:** &nbsp; **D:** &nbsp; **E:** &nbsp; **F:**
#
# **The one that went past the problem, and what it added:**
#
# ---

# %% [markdown]
# **🏠 Optional depth.** Run this on your own if you want to go further.
# **Before you ask:** write one line naming what you already believe is known about
# your topic, so you can tell whether the reply adds anything or just repeats you.
#
# > 💡 **AI Prompt:** "Act as a research-scoping assistant. My topic is [your
# > topic]. List what is already reasonably well established about it and where a
# > genuine open question might remain. For every established fact, give one real,
# > retrievable source I can open myself. Mark anything you are unsure exists."
# >
# > **After running, verify (counters *confident fabrication*, where a fluent answer
# > cites a real-sounding study that does not exist):**
# > - [ ] Open each source yourself before you trust one word of the list. Anything
# >   you cannot retrieve gets cut, not kept.
# > - [ ] Treat the whole list as a map of what might exist, never as evidence of
# >   what does. The real evidence map is Studio 3.
# > - [ ] Log this use in your AI Research Ledger: task, tool, decision,
# >   verification method.

# %% [markdown]
# **🏠 Optional depth.** Run this on your own if you want to go further.
# **Before you ask:** write down the two candidate problems you already hold, so you
# can see whether the table adds a third worth having.
#
# > 💡 **AI Prompt:** "Here is my curiosity: [one sentence]. Produce five candidate
# > research problems inside it. For each, name the unknown it targets, who would
# > care about the answer, and roughly what evidence could speak to it, in a table.
# > Label anything you introduce that my sentence did not contain as NEW. Do not add
# > any topic I did not mention."
# >
# > **After running, verify (counters *silent scope change*, where the tool quietly
# > answers a nearby question and hands it back as yours):**
# > - [ ] Check each row against the curiosity you actually wrote, and mark every
# >   element the table introduced that your sentence did not contain.
# > - [ ] Keep or reject each marked element with a reason. That trail is part of
# >   Friday's artifact, and it is graded.
# > - [ ] Log this use in your AI Research Ledger: task, tool, decision,
# >   verification method.

# %% [markdown]
# **🏠 Optional depth.** Run this on your own if you want to go further.
# This is the attack you will run at Friday's studio, so a practice round now is
# time well spent.
# **Before you ask:** predict the single strongest objection, and write it down.
#
# > 💡 **AI Prompt:** "Act as a hostile grant reviewer. Here is the research problem
# > I want to commit months of work to: [paste it]. Argue the strongest case that it
# > is not worth doing. Attack it on importance, on feasibility, and on whether it
# > adds anything new."
# >
# > **After running, verify (counters *sycophantic agreement*, where a tool praises
# > your idea because you proposed it):**
# > - [ ] If every objection is mild, push back: "assume it is not worth doing, and
# >   name the single worst problem." Weak praise is a red flag, not a result.
# > - [ ] Keep only the objections that survive your own reasoning, and write what
# >   you changed or why you kept the problem as it stands.
# > - [ ] Reject any objection that assumes access or data you never claimed to
# >   have. An invented weakness is not yours to fix.
# > - [ ] Log this use in your AI Research Ledger: task, tool, decision,
# >   verification method.
